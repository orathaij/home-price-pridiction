# %% [markdown]
# Data Preprocessing

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.stats import spearmanr

# %% [markdown]
# Visualize missing values

# %% [markdown]
# นำเข้าข้อมูล
# 1. data_residental_project คือข้อมูลรายละเอียดโครงการที่อยู่อาศัยประเภทจัดสรร ผู้พัฒนา พื้นที่โครงการและสิ่งอำนวนความสะดวกของประเทศไทย
#                                จากการรวบรวมโดย Baania (Thailand)
# 2. data_residental_unittype คือข้อมูลรายละเอียดแบบบ้านในโครงการที่อยู่อาศัยประเภท จัดสรร จากการรวบรวมโดย Baania (Thailand)
# 3. data_city_train_station คือข้อมูลสถานีรถไฟฟ้า ทั้งที่เปิดใช้บริการแล้ว และอยู่ในขั้นตอนของแผนการพัฒนา

# %%
dataset_1 = pd.read_csv('D:/My_IS/Data/for_project/data_residental_project.csv')
dataset_2 = pd.read_csv('D:/My_IS/Data/for_project/data_residental_unittype.csv')
dataset_3 = pd.read_csv('D:/My_IS/Data/for_project/data_city_train_station.csv')

# %%
dataset_1.head()
# Out:
#    row_number                project_id                             name_en  \
# 0      5644.0             project_12591  Supalai Ville Sukhumvit-Srinakarin
# 1     20584.0  5ebb9b0742ad800019cd1546                Wararom Phetkasem 69
# 2     19570.0              project_5363                   Baan Samretvill 1
# 3      7940.0              project_8210                       Baan Thip Net
# 4      7698.0  5f042c65b285eb00194de2f8           Lapista Villa @Yamu Hills
#
#                               name_th propertytype_id propertytype_name_en  \
# 0  ศุภาลัย วิลล์ สุขุมวิท-ศรีนครินทร์               3             Townhome
# 1                 วรารมย์ เพชรเกษม 69               1       Detached House
# 2                   บ้านสำเร็จวิลล์ 1               3             Townhome
# 3                       บ้านทิพย์เนตร               1       Detached House
# 4         ลาพิสต้า วิลล่า @ยามู ฮิลล์               1       Detached House
#
#   propertytype_name_th  price_min              developer_id  \
# 0             ทาวน์โฮม  1840000.0              developer_97
# 1                 บ้าน  2555000.0            developer_1158
# 2             ทาวน์โฮม  1100000.0           developer_10510
# 3                 บ้าน        0.0           developer_10510
# 4                 บ้าน        0.0  5f03f07eb285eb00194de183
#
#                        developer_name_en  ... facility_meeting  facility_park  \
# 0         Supalai Public Company Limited  ...              NaN            1.0
# 1  Quality Houses Public Company Limited  ...              NaN            NaN
# 2                                    NaN  ...              NaN            NaN
# 3                                    NaN  ...              NaN            NaN
# 4             Trillion Estates Co., Ltd.  ...              NaN            NaN
#
#    facility_playground facility_pool facility_security         date_created  \
# 0                  1.0           1.0               1.0  2017-12-15 14:39:29
# 1                  NaN           NaN               1.0  2020-05-13 14:00:23
# 2                  NaN           NaN               NaN  2017-03-28 10:25:41
# 3                  NaN           NaN               NaN  2017-07-04 08:38:26
# 4                  NaN           NaN               NaN  2020-07-07 15:03:49
#
#            date_finish         date_updated  source  \
# 0  2009-12-31 07:00:00  2020-12-04 10:44:32  baania
# 1                  NaN  2022-01-07 18:00:10  baania
# 2  1970-01-02 07:00:00  2020-12-04 10:38:03  baania
# 3  1970-01-02 07:00:00  2020-12-04 10:38:09  baania
# 4                  NaN  2020-12-04 10:33:27  baania
#
#                                          url_project
# 0  https://baania.com/th/project/ศุภาลัย-วิลล์-สุ...
# 1  https://baania.com/th/project/วรารมย์-เพชรเกษม...
# 2  https://baania.com/th/project/บ้านสำเร็จวิลล์-...
# 3  https://baania.com/th/project/บ้านทิพย์เนตร-pr...
# 4  https://baania.com/th/project/ลาพิสต้า-วิลล่า-...
#
# [5 rows x 45 columns]

# %%
dataset_2.head()
# Out:
#    row_number     unittype_id     project_id                   name_th  \
# 0        9921  unittype_32703  project_13900                        S2
# 1       28994   unittype_9841   project_3367     A1-A5 Tower B Floor 2
# 2       13506  unittype_29776  project_12433           ทาวน์โฮมสามชั้น
# 3       25862   unittype_3695    project_541  บ้านเดี่ยวสองชั้น Type B
# 4       32096  unittype_16499   project_6518                2 Bedrooms
#
#    propertytype_id propertytype_name_en propertytype_name_th  \
# 0            20000           Twin house              บ้านแฝด
# 1                2                Condo                คอนโด
# 2                3             Townhome             ทาวน์โฮม
# 3                1       Detached House                 บ้าน
# 4                2                Condo                คอนโด
#
#    area_total_min_wa  area_usable_min  price_min  ...  count_room_guest  \
# 0                NaN            120.0  4900000.0  ...               NaN
# 1                NaN             29.0   897000.0  ...               NaN
# 2                NaN              NaN  2300000.0  ...               NaN
# 3                NaN              NaN        NaN  ...               NaN
# 4                NaN             66.0  4360000.0  ...               NaN
#
#    count_room_kitchen  count_room_living  count_room_maid  count_room_storage  \
# 0                 1.0                1.0              NaN                 NaN
# 1                 NaN                NaN              NaN                 NaN
# 2                 1.0                NaN              NaN                 NaN
# 3                 NaN                NaN              NaN                 NaN
# 4                 1.0                1.0              NaN                 NaN
#
#    count_room_utility         date_created         date_updated  source  \
# 0                 NaN  2022-03-28 10:30:04  2022-03-28 10:24:51  baania
# 1                 NaN  2021-11-12 13:20:52  2020-10-14 00:57:33  baania
# 2                 NaN  2020-12-04 10:42:18  2020-10-14 19:17:28  baania
# 3                 NaN  2020-12-04 10:44:15  2020-10-14 21:17:46  baania
# 4                 NaN  2021-11-12 13:21:33  2020-10-14 01:05:31  baania
#
#                                         url_unittype
# 0  https://baania.com/th/project/บ้านสบาย-วิลเลจ-...
# 1  https://baania.com/th/project/เดอะ-บรีส-คอนโดม...
# 2  https://baania.com/th/project/นวลผกา-เฟส-1-124...
# 3  https://baania.com/th/project/บ้านพิงค์ดอยเพลส...
# 4  https://baania.com/th/project/เดอะ-ราฟเฟิล-651...
#
# [5 rows x 27 columns]

# %%
dataset_3.head()
# Out:
#    row_number  gid  line_no  railway   line_typt line_type    status  \
# 0         312  228        8  รถไฟฟ้า  เอ็มอาร์ที       MRT     อนาคต
# 1         138   91        3  รถไฟฟ้า  เอ็มอาร์ที       MRT  ปัจจุบัน
# 2          46   26        1  รถไฟฟ้า     บีทีเอส       BTS  ปัจจุบัน
# 3         256  109        3  รถไฟฟ้า  เอ็มอาร์ที       MRT  ปัจจุบัน
# 4         318   30        1  รถไฟฟ้า     บีทีเอส       BTS  ปัจจุบัน
#
#         line_th         line_en                  station_th  \
# 0      สายสีส้ม     Orange Line                    สนามหลวง
# 1  สายสีน้ำเงิน       Blue Line  ศูนย์วัฒนธรรมแห่งประเทศไทย
# 2   สายสุขุมวิท  Sukhumvit Line                       พญาไท
# 3  สายสีน้ำเงิน       Blue Line                   ภาษีเจริญ
# 4   สายสุขุมวิท  Sukhumvit Line                    เพลินจิต
#
#                  station_en   latitude   longitude province_name_th  \
# 0               Sanam Luang  13.757770  100.496527    กรุงเทพมหานคร
# 1  Thailand Cultural Centre  13.764791  100.569130    กรุงเทพมหานคร
# 2                Phaya Thai  13.756953  100.533825    กรุงเทพมหานคร
# 3             Phasi Charoen  13.712866  100.433454    กรุงเทพมหานคร
# 4               Phloen Chit  13.743066  100.548995    กรุงเทพมหานคร
#
#   province_name_en district_name_th district_name_en subdistrict_name_th  \
# 0          BANGKOK           พระนคร      PHRA NAKHON             ตลาดยอด
# 1          BANGKOK           ดินแดง        DIN DAENG              ดินแดง
# 2          BANGKOK          ราชเทวี      RATCHATHEWI           ทุ่งพญาไท
# 3          BANGKOK            บางแค        BANG KHAE               บางแค
# 4          BANGKOK          ปทุมวัน       PATHUM WAN             ลุมพินี
#
#   subdistrict_name_en
# 0           TALAT YOT
# 1           DIN DAENG
# 2    THUNG PHAYA THAI
# 3           BANG KHAE
# 4            LUMPHINI

# %% [markdown]
# นำข้อมูลทั้ง 3 ตารางมารวมกัน

# %%
dataset_1_2 = pd.merge(dataset_1, dataset_2,how = 'inner',on ='project_id' )

# %%
dataset = pd.merge(dataset_1_2, dataset_3,how = 'left', on = 'subdistrict_name_en')

# %%
dataset.shape
# Out:
# (79351, 89)

# %%
dataset.columns
# Out:
# Index(['row_number_x', 'project_id', 'name_en', 'name_th_x',
#        'propertytype_id_x', 'propertytype_name_en_x', 'propertytype_name_th_x',
#        'price_min_x', 'developer_id', 'developer_name_en', 'developer_name_th',
#        'latitude_x', 'longitude_x', 'neighborhood_id', 'neighborhood_name_en',
#        'neighborhood_name_th', 'subdistrict_id', 'subdistrict_name_en',
#        'subdistrict_name_th_x', 'district_id', 'district_name_en_x',
#        'district_name_th_x', 'province_id', 'province_name_en_x',
#        'province_name_th_x', 'zipcode', 'count_elevator_x',
#        'count_elevator_service', 'count_floor', 'count_parking_x',
#        'count_tower', 'count_unit', 'count_unittype', 'facility_clubhouse',
#        'facility_fitness', 'facility_meeting', 'facility_park',
#        'facility_playground', 'facility_pool', 'facility_security',
#        'date_created_x', 'date_finish', 'date_updated_x', 'source_x',
#        'url_project', 'row_number_y', 'unittype_id', 'name_th_y',
#        'propertytype_id_y', 'propertytype_name_en_y', 'propertytype_name_th_y',
#        'area_total_min_wa', 'area_usable_min', 'price_min_y',
#        'count_airconditioner', 'count_elevator_y', 'count_floor_internal',
#        'count_parking_y', 'count_room_bath', 'count_room_bed',
#        'count_room_dinning', 'count_room_guest', 'count_room_kitchen',
#        'count_room_living', 'count_room_maid', 'count_room_storage',
#        'count_room_utility', 'date_created_y', 'date_updated_y', 'source_y',
#        'url_unittype', 'row_number', 'gid', 'line_no', 'railway', 'line_typt',
#        'line_type', 'status', 'line_th', 'line_en', 'station_th', 'station_en',
#        'latitude_y', 'longitude_y', 'province_name_th_y', 'province_name_en_y',
#        'district_name_th_y', 'district_name_en_y', 'subdistrict_name_th_y'],
#       dtype='object')

# %%
dataset   =      dataset[['project_id', 'name_en','propertytype_id_x', 
                          'propertytype_name_en_x','developer_id', 
                          'developer_name_en','neighborhood_name_en',
                          'subdistrict_name_en','district_name_en_x',
                          'province_name_en_x' , 'zipcode',
                          'count_elevator_service','count_floor',
                          'count_tower', 'count_unit','count_unittype', 
                          'facility_clubhouse','facility_fitness', 
                          'facility_meeting'  , 'facility_park' ,
                          'facility_playground','facility_pool', 
                          'facility_security','date_finish', 'unittype_id',
                          'area_total_min_wa','area_usable_min','price_min_y',
                          'count_airconditioner', 'count_elevator_y', 
                          'count_floor_internal','count_parking_y',
                          'count_room_bath', 'count_room_bed','count_room_dinning',
                          'count_room_guest'  , 'count_room_kitchen',
                          'count_room_living','count_room_maid','count_room_storage',
                          'count_room_utility', 'gid', 'line_no','railway',
                          'line_type', 'status',  'line_en', 
                          'station_en','latitude_y','longitude_y']]

# %%
dataset.rename(columns = {'propertytype_id_x':'propertytype_id', 
                          'propertytype_name_en_x':'propertytype_name',
                          'name_en':'name','developer_name_en':'developer_name',
                          'neighborhood_name_en':'neighborhood_name',
                          'subdistrict_name_en':'subdistrict_name',
                          'district_name_en_x':'district_name' ,
                          'province_name_en_x':'province_name',
                          'price_min_y':'sale_price',
                          'count_elevator_y':'count_elevator',
                          'count_parking_y':'count_parking',
                          'station_en':'station','latitude_y':'latitude',
                          'longitude_y':'longitude'}, inplace = True)

# %%
dataset.shape
# Out:
# (79351, 50)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79351 entries, 0 to 79350
# Data columns (total 50 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   project_id              79351 non-null  object
#  1   name                    79351 non-null  object
#  2   propertytype_id         79351 non-null  object
#  3   propertytype_name       79351 non-null  object
#  4   developer_id            79351 non-null  object
#  5   developer_name          44801 non-null  object
#  6   neighborhood_name       70089 non-null  object
#  7   subdistrict_name        79328 non-null  object
#  8   district_name           79342 non-null  object
#  9   province_name           79342 non-null  object
#  10  zipcode                 79270 non-null  float64
#  11  count_elevator_service  5085 non-null   object
#  12  count_floor             27365 non-null  object
#  13  count_tower             0 non-null      object
#  14  count_unit              74806 non-null  float64
#  15  count_unittype          65248 non-null  float64
#  16  facility_clubhouse      28978 non-null  float64
#  17  facility_fitness        42631 non-null  float64
#  18  facility_meeting        12438 non-null  float64
#  19  facility_park           48454 non-null  float64
#  20  facility_playground     24329 non-null  float64
#  21  facility_pool           45284 non-null  float64
#  22  facility_security       64277 non-null  float64
#  23  date_finish             72085 non-null  object
#  24  unittype_id             79351 non-null  object
#  25  area_total_min_wa       5815 non-null   float64
#  26  area_usable_min         70019 non-null  float64
#  27  sale_price              66620 non-null  float64
#  28  count_airconditioner    3109 non-null   float64
#  29  count_elevator          0 non-null      float64
#  30  count_floor_internal    51768 non-null  float64
#  31  count_parking           40565 non-null  float64
#  32  count_room_bath         76926 non-null  float64
#  33  count_room_bed          75944 non-null  float64
#  34  count_room_dinning      25018 non-null  float64
#  35  count_room_guest        22620 non-null  float64
#  36  count_room_kitchen      37161 non-null  float64
#  37  count_room_living       19515 non-null  float64
#  38  count_room_maid         3995 non-null   float64
#  39  count_room_storage      6899 non-null   float64
#  40  count_room_utility      1537 non-null   float64
#  41  gid                     38273 non-null  float64
#  42  line_no                 38273 non-null  float64
#  43  railway                 38273 non-null  object
#  44  line_type               38273 non-null  object
#  45  status                  38273 non-null  object
#  46  line_en                 38273 non-null  object
#  47  station                 38273 non-null  object
#  48  latitude                38273 non-null  float64
#  49  longitude               38273 non-null  float64
# dtypes: float64(30), object(20)
# memory usage: 30.9+ MB

# %%
dataset['count_elevator_service'] = pd.to_numeric(dataset['count_elevator_service'])
dataset['count_floor'] = pd.to_numeric(dataset['count_floor'])
dataset['count_tower'] = pd.to_numeric(dataset['count_tower'])

# %%
dataset.nunique()
# Out:
# project_id                20024
# name                      19954
# propertytype_id              11
# propertytype_name            11
# developer_id               3793
# developer_name             2300
# neighborhood_name           969
# subdistrict_name           1053
# district_name               297
# province_name                72
# zipcode                     348
# count_elevator_service       11
# count_floor                  69
# count_tower                   0
# count_unit                 1231
# count_unittype               36
# facility_clubhouse            2
# facility_fitness              2
# facility_meeting              2
# facility_park                 2
# facility_playground           2
# facility_pool                 2
# facility_security             2
# date_finish                 623
# unittype_id               42733
# area_total_min_wa           507
# area_usable_min            1776
# sale_price                 4265
# count_airconditioner         10
# count_elevator                0
# count_floor_internal          9
# count_parking                10
# count_room_bath              13
# count_room_bed               11
# count_room_dinning            2
# count_room_guest              3
# count_room_kitchen            3
# count_room_living             5
# count_room_maid               4
# count_room_storage            5
# count_room_utility            4
# gid                         300
# line_no                      13
# railway                       1
# line_type                     4
# status                        2
# line_en                      13
# station                     258
# latitude                    300
# longitude                   300
# dtype: int64

# %%
dataset.duplicated().sum()
# Out:
# 0

# %% [markdown]
# สำรวจ Missing Value

# %%
categorical_data = dataset.select_dtypes(exclude=[np.number])
numerical_data   = dataset.select_dtypes(include=[np.number])

# %% [markdown]
# สำรวจ Missing Value Categorical data

# %%
missing_values_cat = categorical_data.isnull().sum() / len(categorical_data)
missing_values_cat = missing_values_cat[missing_values_cat > 0]
missing_values_cat.sort_values(inplace=True)
missing_values_cat
# Out:
# district_name        0.000113
# province_name        0.000113
# subdistrict_name     0.000290
# date_finish          0.091568
# neighborhood_name    0.116722
# developer_name       0.435407
# railway              0.517675
# line_type            0.517675
# status               0.517675
# line_en              0.517675
# station              0.517675
# dtype: float64

# %%
#นำข้อมูล missing values มาสร้างเป็น DataFrame
missing_values_cat = pd.DataFrame(missing_values_cat)
missing_values_cat.columns = ['count']
missing_values_cat.index.names = ['Name']
missing_values_cat
# Out:
#                       count
# Name
# district_name      0.000113
# province_name      0.000113
# subdistrict_name   0.000290
# date_finish        0.091568
# neighborhood_name  0.116722
# developer_name     0.435407
# railway            0.517675
# line_type          0.517675
# status             0.517675
# line_en            0.517675
# station            0.517675

# %%
#พล็อตกราฟแท่งแสดง missing values
fig = plt.figure(figsize=(8,5))
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = missing_values_cat.index, y = 'count', data=missing_values_cat)
plt.xlabel('Columns')
plt.xticks(rotation = 90)
plt.show()

# %%
print(missing_values_cat[missing_values_cat['count']>0.4].index)
# Out:
# Index(['developer_name', 'railway', 'line_type', 'status', 'line_en',
#        'station'],
#       dtype='object', name='Name')

# %%
del_cat_col = ['developer_name', 'railway', 'line_type', 'status', 'line_en',
       'station']
dataset.drop(dataset[del_cat_col],axis=1,inplace=True)

# %% [markdown]
# สำรวจ Missing Value Numerical data

# %%
missing_values_numer = numerical_data.isnull().sum() / len(numerical_data)
missing_values_numer = missing_values_numer[missing_values_numer > 0]
missing_values_numer.sort_values(inplace=True)
missing_values_numer
# Out:
# zipcode                   0.001021
# count_room_bath           0.030560
# count_room_bed            0.042936
# count_unit                0.057277
# area_usable_min           0.117604
# sale_price                0.160439
# count_unittype            0.177729
# facility_security         0.189966
# count_floor_internal      0.347607
# facility_park             0.389371
# facility_pool             0.429320
# facility_fitness          0.462754
# count_parking             0.488790
# line_no                   0.517675
# gid                       0.517675
# latitude                  0.517675
# longitude                 0.517675
# count_room_kitchen        0.531688
# facility_clubhouse        0.634812
# count_floor               0.655140
# count_room_dinning        0.684717
# facility_playground       0.693400
# count_room_guest          0.714937
# count_room_living         0.754067
# facility_meeting          0.843253
# count_room_storage        0.913057
# area_total_min_wa         0.926718
# count_elevator_service    0.935918
# count_room_maid           0.949654
# count_airconditioner      0.960820
# count_room_utility        0.980630
# count_elevator            1.000000
# count_tower               1.000000
# dtype: float64

# %%
#นำข้อมูล missing values มาสร้างเป็น DataFrame
missing_values_numer = pd.DataFrame(missing_values_numer)
missing_values_numer.columns = ['count']
missing_values_numer.index.names = ['Name']
missing_values_numer
# Out:
#                            count
# Name
# zipcode                 0.001021
# count_room_bath         0.030560
# count_room_bed          0.042936
# count_unit              0.057277
# area_usable_min         0.117604
# sale_price              0.160439
# count_unittype          0.177729
# facility_security       0.189966
# count_floor_internal    0.347607
# facility_park           0.389371
# facility_pool           0.429320
# facility_fitness        0.462754
# count_parking           0.488790
# line_no                 0.517675
# gid                     0.517675
# latitude                0.517675
# longitude               0.517675
# count_room_kitchen      0.531688
# facility_clubhouse      0.634812
# count_floor             0.655140
# count_room_dinning      0.684717
# facility_playground     0.693400
# count_room_guest        0.714937
# count_room_living       0.754067
# facility_meeting        0.843253
# count_room_storage      0.913057
# area_total_min_wa       0.926718
# count_elevator_service  0.935918
# count_room_maid         0.949654
# count_airconditioner    0.960820
# count_room_utility      0.980630
# count_elevator          1.000000
# count_tower             1.000000

# %%
#พล็อตกราฟแท่งแสดง missing values
fig = plt.figure(figsize=(12,5))
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = missing_values_numer.index, y = 'count', data=missing_values_numer)
plt.xlabel('Columns')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ลบ columns ที่มีค่า missing values มากกว่า 60% ของจำนวนแถวข้อมูลออก

# %%
print(missing_values_numer[missing_values_numer['count']>0.4].index)
# Out:
# Index(['facility_pool', 'facility_fitness', 'count_parking', 'line_no', 'gid',
#        'latitude', 'longitude', 'count_room_kitchen', 'facility_clubhouse',
#        'count_floor', 'count_room_dinning', 'facility_playground',
#        'count_room_guest', 'count_room_living', 'facility_meeting',
#        'count_room_storage', 'area_total_min_wa', 'count_elevator_service',
#        'count_room_maid', 'count_airconditioner', 'count_room_utility',
#        'count_elevator', 'count_tower'],
#       dtype='object', name='Name')

# %%
del_numer_col = ['facility_pool', 'facility_fitness', 'count_parking', 'line_no', 'gid',
       'latitude', 'longitude', 'count_room_kitchen', 'facility_clubhouse',
       'count_floor', 'count_room_dinning', 'facility_playground',
       'count_room_guest', 'count_room_living', 'facility_meeting',
       'count_room_storage', 'area_total_min_wa', 'count_elevator_service',
       'count_room_maid', 'count_airconditioner', 'count_room_utility',
       'count_elevator', 'count_tower']
dataset.drop(dataset[del_numer_col],axis=1,inplace=True)

# %% [markdown]
# เนื่องจากข้อมูลที่ตั้งเป็นข้อมูลที่ค่อนข้างส่งผลต่อราคาบ้าน เราจะทำการ drop ข้อมูล rows ที่ไม่มีข้อมูลใน columns
#
# 'subdistrict_name_en', 'district_name_en', 'province_name_en', 'zipcode'

# %%
location_col = ['subdistrict_name', 'district_name', 'province_name', 'zipcode']
for i in location_col:
    dataset.drop(dataset[dataset[i].isnull() == True].index,inplace=True)

# %% [markdown]
# แทนค่า mean ใน columns ที่เป็น numeric data

# %%
col_fill_numeric = ['count_unit', 'count_unittype', 'facility_park',
       'facility_security', 'area_usable_min', 'sale_price',
       'count_floor_internal', 'count_room_bath', 'count_room_bed']             
for i in col_fill_numeric:
    dataset[i] = dataset[i].fillna(dataset[i].mean())

# %% [markdown]
# columns 'date_finish' จะทำการคำนวณให้ได้จำนวนปีที่สร้างมาใส่ใน columns ใหม่ชื่อว่า 'year_num' แล้วแทนค่า missing ด้วยค่าเฉลี่ย

# %%
from datetime import datetime

# %%
dataset['date_finish'] = pd.to_datetime(dataset['date_finish'])

# %%
current_year = datetime.now().year 
house_year = dataset['date_finish'].dt.year

# %%
dataset['year_num'] = current_year - house_year

# %%
dataset['year_num'].head()
# Out:
# 0    13.0
# 1    13.0
# 2    13.0
# 3    13.0
# 4    13.0
# Name: year_num, dtype: float64

# %%
dataset['year_num'] = dataset['year_num'].fillna(dataset['year_num'].mean())

# %%
dataset.drop(dataset[['date_finish']],axis=1,inplace=True)

# %% [markdown]
# แทนค่า meode ใน columns ที่เป็น category data

# %%
categorical_data.columns
# Out:
# Index(['project_id', 'name', 'propertytype_id', 'propertytype_name',
#        'developer_id', 'developer_name', 'neighborhood_name',
#        'subdistrict_name', 'district_name', 'province_name', 'date_finish',
#        'unittype_id', 'railway', 'line_type', 'status', 'line_en', 'station'],
#       dtype='object')

# %%
def clean(text):
    return text.lower().strip().replace(" ","_")

# %%
col_fill_category =['project_id', 'name', 'propertytype_id', 'propertytype_name',
       'developer_id', 'neighborhood_name','unittype_id']
for i in col_fill_category:
    dataset[i] = dataset[i].astype(str).apply(clean) 
    dataset[i] = dataset[i].fillna(dataset[i].mode().astype(str))

# %%
dataset.isnull().sum().value_counts()
# Out:
# 0    21
# dtype: int64

# %%
cols_to_check = ['province_name']
for i, col in enumerate(cols_to_check):
    print(dataset.groupby(col)[cols_to_check[i]].count())
    print('--------------')
# Out:
# province_name
# Amnat Charoen          34
# Ang Thong               2
# Bangkok             33843
# Bung Kan                2
# Buri Ram               84
#                     ...
# Trat                   15
# Ubon Ratchathani      261
# Udon Thani            469
# Uttaradit              17
# Yasothon                3
# Name: province_name, Length: 72, dtype: int64
# --------------

# %%
province_name_en = dataset["province_name"].astype(str)

# %%
province_name_en = province_name_en.apply(clean)

# %%
dataset["province_name"] = province_name_en

# %%
dataset = dataset[(dataset["province_name"]=="bangkok" )|
                  (dataset["province_name"]=="samut_prakan")|
                  (dataset["province_name"]=="pathum_thani")|
                  (dataset["province_name"]=="samut_sakhon")|
                  (dataset["province_name"]=="nakhon_pathom")|
                  (dataset["province_name"]=="nonthaburi")]

# %%
cols_to_check = ['province_name']
for i, col in enumerate(cols_to_check):
    print(dataset.groupby(col)[cols_to_check[i]].count())
    print('--------------')
# Out:
# province_name
# bangkok          33843
# nakhon_pathom      774
# nonthaburi        8869
# pathum_thani      3798
# samut_prakan      3889
# samut_sakhon      1480
# Name: province_name, dtype: int64
# --------------

# %%
propertytype_name = dataset["propertytype_name"].astype(str)
propertytype_name = propertytype_name.apply(clean)

# %%
dataset["propertytype_name"] = propertytype_name

# %%
cols_to_check = ['propertytype_name']
for i, col in enumerate(cols_to_check):
    print(dataset.groupby(col)[cols_to_check[i]].count())
    print('--------------')
# Out:
# propertytype_name
# apartment                 36
# commercial              1615
# condo                  23169
# detached_house         13076
# home_office              702
# hotel                     32
# land                      12
# office_space              25
# townhome               10938
# twin_house              3036
# warehouse_/_factory       12
# Name: propertytype_name, dtype: int64
# --------------

# %%
dataset = dataset[(dataset["propertytype_name"]=="condo" )|
                  (dataset["propertytype_name"]=="detached_house")|
                  (dataset["propertytype_name"]=="townhome")|
                  (dataset["propertytype_name"]=="twin_house")]

# %%
cols_to_check = ['propertytype_name']
for i, col in enumerate(cols_to_check):
    print(dataset.groupby(col)[cols_to_check[i]].count())
    print('--------------')
# Out:
# propertytype_name
# condo             23169
# detached_house    13076
# townhome          10938
# twin_house         3036
# Name: propertytype_name, dtype: int64
# --------------

# %%
dataset.shape
# Out:
# (50219, 21)

# %%
dataset.head()
# Out:
#       project_id                                name propertytype_id  \
# 0  project_12591  supalai_ville_sukhumvit-srinakarin               3
# 1  project_12591  supalai_ville_sukhumvit-srinakarin               3
# 2  project_12591  supalai_ville_sukhumvit-srinakarin               3
# 3  project_12591  supalai_ville_sukhumvit-srinakarin               1
# 4  project_12591  supalai_ville_sukhumvit-srinakarin               1
#
#   propertytype_name  developer_id neighborhood_name subdistrict_name  \
# 0          townhome  developer_97       dan_samrong     SAMRONG NUEA
# 1          townhome  developer_97       dan_samrong     SAMRONG NUEA
# 2          townhome  developer_97       dan_samrong     SAMRONG NUEA
# 3    detached_house  developer_97       dan_samrong     SAMRONG NUEA
# 4    detached_house  developer_97       dan_samrong     SAMRONG NUEA
#
#          district_name province_name  zipcode  ...  count_unittype  \
# 0  MUEANG SAMUT PRAKAN  samut_prakan  10270.0  ...             3.0
# 1  MUEANG SAMUT PRAKAN  samut_prakan  10270.0  ...             3.0
# 2  MUEANG SAMUT PRAKAN  samut_prakan  10270.0  ...             3.0
# 3  MUEANG SAMUT PRAKAN  samut_prakan  10270.0  ...             3.0
# 4  MUEANG SAMUT PRAKAN  samut_prakan  10270.0  ...             3.0
#
#    facility_park  facility_security     unittype_id area_usable_min  \
# 0            1.0                1.0  unittype_29995           135.0
# 1            1.0                1.0  unittype_29993           146.0
# 2            1.0                1.0  unittype_29994            89.0
# 3            1.0                1.0  unittype_29995           135.0
# 4            1.0                1.0  unittype_29993           146.0
#
#    sale_price  count_floor_internal  count_room_bath  count_room_bed  year_num
# 0   3350000.0                   3.0              3.0             3.0      13.0
# 1   4641000.0                   2.0              3.0             4.0      13.0
# 2   1840000.0                   2.0              3.0             3.0      13.0
# 3   3350000.0                   3.0              3.0             3.0      13.0
# 4   4641000.0                   2.0              3.0             4.0      13.0
#
# [5 rows x 21 columns]

# %% [markdown]
# สำรวจค่าผิดปกติ (Outliers)

# %% [markdown]
# พล็อตข้อมูลในคอลัมน์ sale_price โดยใช้ฟังก์ชัน boxplot ของ seaborn

# %%
fig = plt.figure(figsize=(15,4))
sns.boxplot(x=(dataset['sale_price'])/1000000, color='lime')
plt.xlabel('Sale Price (Million Baht)', fontsize=25)
plt.show()

# %% [markdown]
# ในคอลัมน์ sale_price ของข้อมูลตัวอย่างมี Outlier อยู่ ทำการคำนวณ IQR

# %%
Q1 = dataset['sale_price'].quantile(0.25)
Q3 = dataset['sale_price'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# 3944689.585332131

# %% [markdown]
# คำนวณ Lower Fence และ Upper Fence

# %%
lower_fence = Q1 - (1.5*IQR)
upper_fence = Q3 + (1.5*IQR)
print('Lower Fence: ', lower_fence)
print('Upper Fence: ', upper_fence)
# Out:
# Lower Fence:  -3627034.3779981965
# Upper Fence:  12151723.963330328

# %% [markdown]
# ตรวจสอบข้อมูลที่มีคอลัมน์ sale_price ที่ต่ำกว่า Lower Fence และสูงกว่า Upper Fence

# %%
dataset[((dataset['sale_price'] < lower_fence) |(dataset['sale_price'] > upper_fence))].sale_price.sort_values()
# Out:
# 29784     12190000.0
# 29785     12190000.0
# 57260     12200000.0
# 57259     12200000.0
# 57258     12200000.0
#             ...
# 75925    400000000.0
# 75924    400000000.0
# 75923    400000000.0
# 45509    580000000.0
# 45508    580000000.0
# Name: sale_price, Length: 5458, dtype: float64

# %% [markdown]
# นำเอา Outliers ออกไปจาก DataFrame

# %%
df_no_outlier = dataset[~((dataset['sale_price'] < lower_fence)|(dataset['sale_price'] > upper_fence))]

# %%
df_no_outlier.sale_price.describe()
# Out:
# count    4.476100e+04
# mean     4.141818e+06
# std      2.531815e+06
# min      1.000000e+05
# 25%      2.000000e+06
# 50%      3.690000e+06
# 75%      6.234690e+06
# max      1.210000e+07
# Name: sale_price, dtype: float64

# %%
fig = plt.figure(figsize=(15,4))
sns.boxplot(x=df_no_outlier['sale_price']/1000000, color='lime')
plt.xlabel('Sale Price (Million Baht)', fontsize=25)
plt.show()

# %% [markdown]
# สำรวจการกระจายของข้อมูล

# %%
sns.histplot(df_no_outlier.sale_price/1000000, kde=True,bins=20)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
print(df_no_outlier.select_dtypes(exclude=[np.number]).columns)
# Out:
# Index(['project_id', 'name', 'propertytype_id', 'propertytype_name',
#        'developer_id', 'neighborhood_name', 'subdistrict_name',
#        'district_name', 'province_name', 'unittype_id'],
#       dtype='object')

# %%
df_no_outlier.loc[:,df_no_outlier.dtypes == 'object'] = (df_no_outlier.select_dtypes(['object']).astype(str))
# Out:
# c:\Users\Admin\.conda\envs\myenv\lib\site-packages\pandas\core\indexing.py:1717: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, v)

# %%
lebel = LabelEncoder()
col_to_label = ['project_id', 'name', 'propertytype_id', 'propertytype_name',
                'developer_id', 'neighborhood_name', 'subdistrict_name',
                'district_name', 'province_name', 'unittype_id']
for i in col_to_label:
    df_no_outlier[i] = lebel.fit_transform(df_no_outlier[i])
# Out:
# c:\Users\Admin\.conda\envs\myenv\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_no_outlier.head()
# Out:
#    project_id  name  propertytype_id  propertytype_name  developer_id  \
# 0        2163  8159                3                  2          1576
# 1        2163  8159                3                  2          1576
# 2        2163  8159                3                  2          1576
# 3        2163  8159                0                  1          1576
# 4        2163  8159                0                  1          1576
#
#    neighborhood_name  subdistrict_name  district_name  province_name  zipcode  \
# 0                 96               282             44              4  10270.0
# 1                 96               282             44              4  10270.0
# 2                 96               282             44              4  10270.0
# 3                 96               282             44              4  10270.0
# 4                 96               282             44              4  10270.0
#
#    ...  count_unittype  facility_park  facility_security  unittype_id  \
# 0  ...             3.0            1.0                1.0        14522
# 1  ...             3.0            1.0                1.0        14520
# 2  ...             3.0            1.0                1.0        14521
# 3  ...             3.0            1.0                1.0        14522
# 4  ...             3.0            1.0                1.0        14520
#
#    area_usable_min  sale_price  count_floor_internal  count_room_bath  \
# 0            135.0   3350000.0                   3.0              3.0
# 1            146.0   4641000.0                   2.0              3.0
# 2             89.0   1840000.0                   2.0              3.0
# 3            135.0   3350000.0                   3.0              3.0
# 4            146.0   4641000.0                   2.0              3.0
#
#    count_room_bed  year_num
# 0             3.0      13.0
# 1             4.0      13.0
# 2             3.0      13.0
# 3             3.0      13.0
# 4             4.0      13.0
#
# [5 rows x 21 columns]

# %%
sns.jointplot(x = df_no_outlier['area_usable_min'], y = df_no_outlier['sale_price']/1000000)

# %%
sns.jointplot(x=df_no_outlier['count_unittype'], y=df_no_outlier['sale_price']/1000000)

# %%
sns.jointplot(x=df_no_outlier['count_room_bath'], y=df_no_outlier['sale_price']/1000000)

# %% [markdown]
# หาค่า Correlation Score และพล็อต Correlation Heatmap โดยใช้ Seaborn Library

# %%
corr = df_no_outlier.corr()
corr.shape
# Out:
# (21, 21)

# %%
plt.figure(figsize=(12,12))
sns.heatmap(corr, cbar=True, square= True, fmt='.1f', annot=True, annot_kws={'size':15}, cmap='Greens')
# Out:
# <AxesSubplot:>

# %%
print (corr['sale_price'].sort_values(ascending=False)[:10]) #top 10 correlations
print (corr['sale_price'].sort_values(ascending=False)[-5:]) #least 5 correlations
# Out:
# sale_price              1.000000
# count_room_bath         0.444089
# area_usable_min         0.427919
# count_room_bed          0.403234
# count_floor_internal    0.173060
# district_name           0.120367
# facility_park           0.108626
# facility_security       0.056107
# subdistrict_name        0.055760
# propertytype_name       0.052435
# Name: sale_price, dtype: float64
# year_num          -0.143348
# province_name     -0.165899
# project_id        -0.169256
# count_unit        -0.181784
# propertytype_id   -0.195101
# Name: sale_price, dtype: float64

# %%
# Spliting target variable and independent variables
X = df_no_outlier.drop(['sale_price'], axis = 1)
y = df_no_outlier['sale_price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.25, random_state = 4)

# %% [markdown]
# Linear regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline

# Create a Linear regressor
lm = LinearRegression()

# Train the model using the training sets 
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Model prediction on train data
y_pred = lm.predict(X_train)

# %%
def MAPE(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
# Model Evaluation
from sklearn import metrics
print('MAPE:','%.2f' %MAPE(y_train, y_pred),'%')
print('R^2:',metrics.r2_score(y_train, y_pred))
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_train, y_pred))*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_train, y_pred))
print('MSE:',metrics.mean_squared_error(y_train, y_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_train, y_pred)))
# Out:
# MAPE: 61.19 %
# R^2: 0.4059060800964318
# Adjusted R^2: 0.40555191519142497
# MAE: 1512001.6722462676
# MSE: 3834144391236.52
# RMSE: 1958097.135291434

# %%
# Visualizing the differences between actual prices and predicted values
plt.scatter(y_train/1000000, y_pred/1000000)
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
plt.show()

# %%
# Checking residuals
plt.scatter(y_pred/1000000,(y_train-y_pred)/1000000)
plt.title("Predicted vs residuals")
plt.xlabel("Predicted")
plt.ylabel("Residuals")
plt.show()

# %%
# Predicting Test data with the model
y_test_pred = lm.predict(X_test)

# %%
# Model Evaluation
acc_linreg = metrics.r2_score(y_test, y_test_pred)
mape_linreg = MAPE(y_test, y_test_pred)
print('MAPE:','%.2f' %mape_linreg,'%')
print('R^2:', acc_linreg)
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_test, y_test_pred))*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_test, y_test_pred))
print('MSE:',metrics.mean_squared_error(y_test, y_test_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
# Out:
# MAPE: 60.97 %
# R^2: 0.39463398034558805
# Adjusted R^2: 0.39355006625489086
# MAE: 1490920.5509096265
# MSE: 3800556728051.8594
# RMSE: 1949501.661464247

# %% [markdown]
# Random Forest Regressor

# %%
# Import Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor

# Create a Random Forest Regressor
reg = RandomForestRegressor()

# Train the model using the training sets 
reg.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# Model prediction on train data
y_pred = reg.predict(X_train)

# %%
# Model Evaluation
print('MAPE:','%.2f' %MAPE(y_train, y_pred),'%')
print('R^2:',metrics.r2_score(y_train, y_pred))
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_train, y_pred))*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_train, y_pred))
print('MSE:',metrics.mean_squared_error(y_train, y_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_train, y_pred)))
# Out:
# MAPE: 5.48 %
# R^2: 0.9839690658656185
# Adjusted R^2: 0.9839595091371709
# MAE: 164319.69169863313
# MSE: 103459931398.72208
# RMSE: 321651.87920906366

# %%
# Visualizing the differences between actual prices and predicted values
plt.scatter(y_train/1000000, y_pred/1000000)
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
plt.show()

# %%
# Checking residuals
plt.scatter(y_pred/1000000,(y_train-y_pred)/1000000)
plt.title("Predicted vs residuals")
plt.xlabel("Predicted")
plt.ylabel("Residuals")
plt.show()

# %%
# Predicting Test data with the model
y_test_pred = reg.predict(X_test)

# %%
# Model Evaluation
acc_rf = metrics.r2_score(y_test, y_test_pred)
mape_rf = MAPE(y_test, y_test_pred)
print('MAPE:','%.2f' %mape_rf,'%')
print('R^2:', acc_rf)
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_test, y_test_pred))*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_test, y_test_pred))
print('MSE:',metrics.mean_squared_error(y_test, y_test_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
# Out:
# MAPE: 14.54 %
# R^2: 0.8794544511183316
# Adjusted R^2: 0.8792386130719902
# MAE: 448948.91651051975
# MSE: 756798667193.8895
# RMSE: 869941.7608057965

# %% [markdown]
# XGBoost Regressor

# %%
# Import XGBoost Regressor
from xgboost import XGBRegressor

#Create a XGBoost Regressor
reg = XGBRegressor()

# Train the model using the training sets 
reg.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
# Model prediction on train data
y_pred = reg.predict(X_train)

# %%
# Model Evaluation
print('MAPE:','%.2f' %MAPE(y_train, y_pred),'%')
print('R^2:',metrics.r2_score(y_train, y_pred))
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_train, y_pred))*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_train, y_pred))
print('MSE:',metrics.mean_squared_error(y_train, y_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_train, y_pred)))
# Out:
# MAPE: 20.21 %
# R^2: 0.885593110130817
# Adjusted R^2: 0.8855249072694088
# MAE: 602844.5946978759
# MSE: 738355536750.7266
# RMSE: 859276.1702448908

# %%
# Visualizing the differences between actual prices and predicted values
plt.scatter(y_train/1000000, y_pred/1000000)
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
plt.show()

# %%
# Checking residuals
plt.scatter(y_pred/1000000,(y_train-y_pred)/1000000)
plt.title("Predicted vs residuals")
plt.xlabel("Predicted")
plt.ylabel("Residuals")
plt.show()

# %%
#Predicting Test data with the model
y_test_pred = reg.predict(X_test)

# %%
# Model Evaluation
acc_xgb = metrics.r2_score(y_test, y_test_pred)
mape_xgb = MAPE(y_test, y_test_pred)
print('MAPE:','%.2f' %mape_xgb,'%')
print('R^2:', acc_xgb)
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_test, y_test_pred))*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_test, y_test_pred))
print('MSE:',metrics.mean_squared_error(y_test, y_test_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
# Out:
# MAPE: 23.79 %
# R^2: 0.8219669501042768
# Adjusted R^2: 0.8216481800955109
# MAE: 725342.0565787416
# MSE: 1117711737409.7927
# RMSE: 1057218.8692081657

# %% [markdown]
# Evaluation and comparision of all the models

# %%
models = pd.DataFrame({
    'Model': ['Linear Regression', 'Random Forest', 'XGBoost'],
    'R-squared Score': [acc_linreg, acc_rf, acc_xgb],
    'Mean absolute percentage error': ['%.2f' %mape_linreg, '%.2f' %mape_rf, '%.2f' %mape_xgb]})
models.sort_values(by='R-squared Score', ascending=False)
# Out:
#                Model  R-squared Score Mean absolute percentage error
# 1      Random Forest         0.879454                          14.54
# 2            XGBoost         0.821967                          23.79
# 0  Linear Regression         0.394634                          60.97
